# %%
# !printenv | grep -i ROS
# Out:
# ROS_VERSION=2
# ROS_PYTHON_VERSION=3
# AMENT_PREFIX_PATH=/opt/ros/kilted
# CMAKE_PREFIX_PATH=/opt/ros/kilted/opt/gz_math_vendor:/opt/ros/kilted/opt/gz_utils_vendor:/opt/ros/kilted/opt/gz_cmake_vendor
# ROS_AUTOMATIC_DISCOVERY_RANGE=SUBNET
# PYTHONPATH=/opt/ros/kilted/lib/python3.12/site-packages
# LD_LIBRARY_PATH=/opt/ros/kilted/opt/gz_math_vendor/lib:/opt/ros/kilted/opt/gz_utils_vendor/lib:/opt/ros/kilted/opt/rviz_ogre_vendor/lib:/opt/ros/kilted/lib/x86_64-linux-gnu:/opt/ros/kilted/opt/gz_cmake_vendor/lib:/opt/ros/kilted/lib
# PATH=/opt/ros/kilted/bin:/home/anurag/Documents/NextAISenseRepo/RoboticsTutorial/venv/bin:/home/anurag/.local/bin:/home/anurag/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/snap/bin
# ROS_DISTRO=kilted

# %%
<link name="link1">
    <visual>
        <geometry>
            <cylinder radius="0.05" length="0.3"/>
        </geometry>
    </visual>
</link>
# Out:
#   Cell In[3], line 1
#     <link name="link1">
#     ^
# SyntaxError: invalid syntax
